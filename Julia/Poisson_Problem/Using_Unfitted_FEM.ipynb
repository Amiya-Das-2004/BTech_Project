# %%
using STLCutters, Gridap, GridapEmbedded, PartitionedArrays

# %%
# Only used in unfitted FEM

# %%
methods(CartesianDiscreteModel)
# Out:
# # 8 methods for type constructor:
#  [1] CartesianDiscreteModel(parts::Nothing, args...; kwargs...)
#      @ C:\Users\IIT BBSR\.julia\packages\Gridap\dk0DA\src\Geometry\CartesianDiscreteModels.jl:80
#  [2] CartesianDiscreteModel(pdesc::GridapDistributed.DistributedCartesianDescriptor)
#      @ GridapDistributed C:\Users\IIT BBSR\.julia\packages\GridapDistributed\XNMqm\src\Geometry.jl:330
#  [3] CartesianDiscreteModel(grid::CartesianGrid{D, T, F}, grid_topology::Gridap.Geometry.UnstructuredGridTopology{D, D, T, Gridap.Geometry.Oriented}, face_labeling::Gridap.Geometry.FaceLabeling) where {D, T, F}
#      @ C:\Users\IIT BBSR\.julia\packages\Gridap\dk0DA\src\Geometry\CartesianDiscreteModels.jl:8
#  [4] CartesianDiscreteModel(ranks::AbstractArray{<:Integer}, parts::NTuple{N, var"#s7"} where var"#s7"<:Integer, args...; ghost, kwargs...) where N
#      @ GridapDistributed C:\Users\IIT BBSR\.julia\packages\GridapDistributed\XNMqm\src\Geometry.jl:318
# ...

# %%
methods(cut)
# Out:
# # 11 methods for generic function "cut" from GridapEmbedded.Interfaces:
#   [1] cut(cutter::LevelSetCutter, background::DiscreteModel, geom)
#      @ GridapEmbedded.LevelSetCutters C:\Users\IIT BBSR\.julia\packages\GridapEmbedded\PIAqm\src\LevelSetCutters\LevelSetCutters.jl:79
#   [2] cut(cutter::STLCutter, background::DiscreteModel, geom::STLGeometry)
#      @ STLCutters C:\Users\IIT BBSR\.julia\packages\STLCutters\oEu9o\src\Embedded.jl:143
#   [3] cut(cutter::STLCutter, bgmodel::GridapDistributed.DistributedDiscreteModel, args...)
#      @ STLCutters C:\Users\IIT BBSR\.julia\packages\STLCutters\oEu9o\src\Distributed.jl:6
#   [4] cut(cutter::GridapEmbedded.Interfaces.Cutter, bgmodel::GridapDistributed.DistributedDiscreteModel, geom::GridapEmbedded.Distributed.DistributedDiscreteGeometry)
#      @ GridapEmbedded.Distributed C:\Users\IIT BBSR\.julia\packages\GridapEmbedded\PIAqm\src\Distributed\DistributedDiscreteGeometries.jl:26
# ...
