# %%
using Gridap, Gridap.Adaptivity, Gridap.Geometry
using GridapEmbedded, GridapEmbedded.LevelSetCutters
using GridapTopOpt, GridapSolvers

using GridapTopOpt: StateParamMap

"""
  (Serial) Minimum thermal compliance with a CutFEM formulation based on Burman et al. (2015)
    [10.1002/nme.4823] & automatic shape differentiation in 2D.

  Optimisation problem:
      Min J(Ω) = ∫ ∇(u)⋅∇(u) dΩ
       Ω
    s.t., Vol(Ω) = 0.3,
          ⎡u∈V=H¹(Ω;u(Γ_D)=0),
          ⎣∫ ∇(u)⋅∇(v) dΩ + j(u,v) + i(u,v) = ∫ v dΓ_N, ∀v∈V.

  In the above, j(u,v) is the ghost penalty term over the ghost skeleton Γg
  with outward normal n_Γg, and i(u,v) enforces zero temperature within the
  isolated volumes marked by χ. These are given by
      j(u,v) = ∫ γh[[∇(u)⋅n_Γg]][[(∇(v)⋅n_Γg]] dΓg, &
      i(u,v) = ∫ χuv dΩ.
"""
function main()
  path="./results/Unfitted_Thermal2D/"
  mkpath(path)
  # Params
  n = 50            # Initial mesh size (pre-refinement)
  max_steps = n/5   # Time-steps for evolution equation
  vf = 0.3          # Volume fraction
  α_coeff = 2       # Regularisation coefficient extension-regularisation
  iter_mod = 10     # Write output every iter_mod iterations

  # Model and some refinement
  _model = CartesianDiscreteModel((0,1,0,1),(n,n))
  base_model = UnstructuredDiscreteModel(_model)
  ref_model = refine(base_model, refinement_method = "barycentric")
  ref_model = refine(ref_model)
  ref_model = refine(ref_model)
  model = ref_model.model
  h = minimum(get_element_diameters(model))
  hₕ = get_element_diameter_field(model)
  f_Γ_D(x) = (x[1]-0.5)^2 + (x[2]-0.5)^2 <= 0.05^2
  f_Γ_N(x) = ((x[1] ≈ 0 || x[1] ≈ 1) && (0.2 <= x[2] <= 0.3 + eps() || 0.7 - eps() <= x[2] <= 0.8)) ||
    ((x[2] ≈ 0 || x[2] ≈ 1) && (0.2 <= x[1] <= 0.3 + eps() || 0.7 - eps() <= x[1] <= 0.8))
  update_labels!(1,model,f_Γ_D,"Omega_D")
  update_labels!(2,model,f_Γ_N,"Gamma_N")
  writevtk(model,path*"model")

  ## Levet-set function space and derivative regularisation space
  reffe_scalar = ReferenceFE(lagrangian,Float64,1)
  V_reg = TestFESpace(model,reffe_scalar;dirichlet_tags=["Omega_D","Gamma_N"])
  U_reg = TrialFESpace(V_reg)
  V_φ = TestFESpace(model,reffe_scalar)

  ## Level-set function
  f1 = (x,y) -> -cos(6π*(x-1/12))*cos(6π*(y-1/12))-0.5
  f2 = (x,y) -> -cos(6π*(x-3/12))*cos(6π*(y-1/12))-0.5
  f3 = (x,y) -> (x-0.5)^2 + (y-0.5)^2 - 0.06^2
  f((x,y)) = min(max(f1(x,y),f2(x,y)),f3(x,y))
  φh = interpolate(f,V_φ)

  # Check LS
  GridapTopOpt.correct_ls!(φh)

  ## Triangulations and measures
  Ω_bg = Triangulation(model)
  Γ_N = BoundaryTriangulation(model,tags="Gamma_N")
  dΩ_bg = Measure(Ω_bg,2)
  dΓ_N = Measure(Γ_N,2)
  vol_D = sum(∫(1)dΩ_bg)

  Ωs = EmbeddedCollection(model,φh) do cutgeo,cutgeo_facets,_φh
    Ωin = DifferentiableTriangulation(Triangulation(cutgeo,PHYSICAL),V_φ)
    Γ = DifferentiableTriangulation(EmbeddedBoundary(cutgeo),V_φ)
    Γg = GhostSkeleton(cutgeo)
    Ωact = Triangulation(cutgeo,ACTIVE)
    # Isolated volumes
    φ_cell_values = get_cell_dof_values(_φh)
    χ,_ = get_isolated_volumes_mask_polytopal(model,φ_cell_values,["Omega_D",])
    (;
      :Ωin  => Ωin,
      :dΩin => Measure(Ωin,2),
      :Γg   => Γg,
      :dΓg  => Measure(Γg,2),
      :n_Γg => get_normal_vector(Γg),
      :Γ    => Γ,
      :dΓ   => Measure(Γ,2),
      :n_Γ  => get_normal_vector(Γ),
      :Ωact => Ωact,
      :χ => χ
    )
  end

  ## Weak form
  γg = 0.1
  a(u,v,φ) = ∫(∇(v)⋅∇(u))Ωs.dΩin +
    ∫((γg*mean(hₕ))*jump(Ωs.n_Γg⋅∇(v))*jump(Ωs.n_Γg⋅∇(u)))Ωs.dΓg +
    ∫(Ωs.χ*v*u)Ωs.dΩin
  l(v,φ) = ∫(v)dΓ_N

  ## Optimisation functionals
  J(u,φ) = ∫(∇(u)⋅∇(u))Ωs.dΩin
  Vol(u,φ) = ∫(1/vol_D)Ωs.dΩin - ∫(vf/vol_D)dΩ_bg
  dVol(q,u,φ) = ∫(-1/vol_D*q/(abs(Ωs.n_Γ ⋅ ∇(φ))))Ωs.dΓ

  ## FE operators
  state_collection = EmbeddedCollection_in_φh(model,φh) do _φh
    update_collection!(Ωs,_φh)
    V = TestFESpace(Ωs.Ωact,reffe_scalar;dirichlet_tags=["Omega_D"])
    U = TrialFESpace(V,0.0)
    state_map = AffineFEStateMap(a,l,U,V,V_φ)
    (;
      :state_map => state_map,
      :J => StateParamMap(J,state_map),
      :C => map(Ci -> StateParamMap(Ci,state_map),[Vol,])
    )
  end
  pcfs = EmbeddedPDEConstrainedFunctionals(state_collection;analytic_dC=(dVol,))

  ## Evolution Method
  evo = CutFEMEvolver(V_φ,Ωs,dΩ_bg,hₕ;max_steps,γg=0.1)
  reinit = StabilisedReinitialiser(V_φ,Ωs,dΩ_bg,hₕ;stabilisation_method=ArtificialViscosity(2.0))
  ls_evo = LevelSetEvolution(evo,reinit)
  reinit!(ls_evo,φh)

  ## Hilbertian extension-regularisation problems
  α = (α_coeff)^2*hₕ*hₕ
  a_hilb(p,q) =∫(α*∇(p)⋅∇(q) + p*q)dΩ_bg;
  vel_ext = VelocityExtension(a_hilb,U_reg,V_reg)

  ## Optimiser
  converged(m) = GridapTopOpt.default_al_converged(
    m;
    L_tol = 0.01*h,
    C_tol = 0.01
  )
  optimiser = AugmentedLagrangian(pcfs,ls_evo,vel_ext,φh;verbose=true,constraint_names=[:Vol],converged)
  for (it,uh,φh) in optimiser
    if iszero(it % iter_mod)
      writevtk(Ω_bg,path*"Omega$it",cellfields=["φ"=>φh,"|∇(φ)|"=>(norm ∘ ∇(φh)),"uh"=>uh,"χ"=>Ωs.χ])
      writevtk(Ωs.Ωin,path*"Omega_in$it",cellfields=["uh"=>uh])
    end
    write_history(path*"/history.txt",optimiser.history)
  end
  it = get_history(optimiser).niter; uh = get_state(pcfs)
  writevtk(Ω_bg,path*"Omega$it",cellfields=["φ"=>φh,"|∇(φ)|"=>(norm ∘ ∇(φh)),"uh"=>uh,"χ"=>Ωs.χ])
  writevtk(Ωs.Ωin,path*"Omega_in$it",cellfields=["uh"=>uh])
end

main()
# Out:
# --------------- Starting Newton-Raphson solver --------
#   > Iteration   0 - Residuals: 7.25e-02,   1.00e+00
#   > Iteration   1 - Residuals: 2.53e-03,   3.48e-02
#   > Iteration   2 - Residuals: 3.78e-04,   5.22e-03
#   > Iteration   3 - Residuals: 4.53e-05,   6.24e-04
#   > Iteration   4 - Residuals: 9.81e-07,   1.35e-05
#   > Iteration   5 - Residuals: 1.76e-09,   2.43e-08
#   > Iteration   6 - Residuals: 1.09e-11,   1.50e-10
#   > Iteration   7 - Residuals: 1.62e-13,   2.24e-12
# Solver Newton-Raphson finished with reason SOLVER_CONVERGED_ATOL
# Iterations:   7 - Residuals: 1.62e-13,   2.24e-12
# --------------- Exiting Newton-Raphson solver ---------
# --------------- Starting Newton-Raphson solver --------
#   > Iteration   0 - Residuals: 9.67e-04,   1.00e+00
#   > Iteration   1 - Residuals: 1.70e-06,   1.76e-03
#   > Iteration   2 - Residuals: 1.14e-08,   1.18e-05
#   > Iteration   3 - Residuals: 1.35e-10,   1.40e-07
#   > Iteration   4 - Residuals: 2.63e-12,   2.72e-09
#   > Iteration   5 - Residuals: 4.59e-14,   4.75e-11
# Solver Newton-Raphson finished with reason SOLVER_CONVERGED_ATOL
# Iterations:   5 - Residuals: 4.59e-14,   4.75e-11
# --------------- Exiting Newton-Raphson solver ---------
# Iteration:   0 | L=6.0300e-01, J=5.8612e-01, Vol=3.3183e-01, γ=1.0000e-01, λ1=0.0000e+00, Λ1=3.0662e-01
# --------------- Starting Newton-Raphson solver --------
#   > Iteration   0 - Residuals: 6.62e-04,   1.00e+00
#   > Iteration   1 - Residuals: 2.62e-06,   3.96e-03
#   > Iteration   2 - Residuals: 2.70e-08,   4.07e-05
#   > Iteration   3 - Residuals: 6.02e-10,   9.09e-07
#   > Iteration   4 - Residuals: 1.06e-11,   1.60e-08
#   > Iteration   5 - Residuals: 2.73e-13,   4.12e-10
# Solver Newton-Raphson finished with reason SOLVER_CONVERGED_ATOL
# Iterations:   5 - Residuals: 2.73e-13,   4.12e-10
# --------------- Exiting Newton-Raphson solver ---------
# Iteration:   1 | L=5.7870e-01, J=5.6141e-01, Vol=3.3581e-01, γ=1.0000e-01, λ1=-1.0297e-01, Λ1=3.0662e-01
# --------------- Starting Newton-Raphson solver --------
#   > Iteration   0 - Residuals: 6.34e-04,   1.00e+00
#   > Iteration   1 - Residuals: 4.51e-06,   7.11e-03
#   > Iteration   2 - Residuals: 3.35e-08,   5.28e-05
#   > Iteration   3 - Residuals: 8.35e-10,   1.32e-06
#   > Iteration   4 - Residuals: 1.84e-11,   2.90e-08
#   > Iteration   5 - Residuals: 6.29e-13,   9.92e-10
# Solver Newton-Raphson finished with reason SOLVER_CONVERGED_ATOL
# Iterations:   5 - Residuals: 6.29e-13,   9.92e-10
# --------------- Exiting Newton-Raphson solver ---------
# Iteration:   2 | L=5.8752e-01, J=5.3443e-01, Vol=3.4176e-01, γ=1.0000e-01, λ1=-2.0776e-01, Λ1=3.0662e-01
# --------------- Starting Newton-Raphson solver --------
#   > Iteration   0 - Residuals: 6.44e-04,   1.00e+00
#   > Iteration   1 - Residuals: 4.23e-06,   6.57e-03
#   > Iteration   2 - Residuals: 3.65e-08,   5.66e-05
#   > Iteration   3 - Residuals: 9.54e-10,   1.48e-06
#   > Iteration   4 - Residuals: 3.03e-11,   4.71e-08
#   > Iteration   5 - Residuals: 1.08e-12,   1.68e-09
#   > Iteration   6 - Residuals: 3.80e-14,   5.90e-11
# Solver Newton-Raphson finished with reason SOLVER_CONVERGED_ATOL
# Iterations:   6 - Residuals:
# Solver Newton-Raphson finished with reason SOLVER_CONVERGED_ATOL
# Iterations:   7 - Residuals: 6.37e-13,   1.11e-09
# --------------- Exiting Newton-Raphson solver ---------
# Iteration: 115 | L=5.8167e-01, J=5.8311e-01, Vol=-7.4991e-04, γ=7.5000e-02, λ1=-1.9185e+00, Λ1=1.1644e+00
# --------------- Starting Newton-Raphson solver --------
#   > Iteration   0 - Residuals: 5.75e-04,   1.00e+00
#   > Iteration   1 - Residuals: 6.01e-06,   1.05e-02
#   > Iteration   2 - Residuals: 2.96e-07,   5.15e-04
#   > Iteration   3 - Residuals: 1.97e-08,   3.43e-05
#   > Iteration   4 - Residuals: 1.16e-09,   2.01e-06
#   > Iteration   5 - Residuals: 7.48e-11,   1.30e-07
#   > Iteration   6 - Residuals: 5.86e-12,   1.02e-08
#   > Iteration   7 - Residuals: 4.54e-13,   7.89e-10
# Solver Newton-Raphson finished with reason SOLVER_CONVERGED_ATOL
# Iterations:   7 - Residuals: 4.54e-13,   7.89e-10
# --------------- Exiting Newton-Raphson solver ---------
# Iteration: 116 | L=5.8168e-01, J=5.8293e-01, Vol=-6.5131e-04, γ=7.5000e-02, λ1=-1.9178e+00, Λ1=1.1644e+00
# --------------- Starting Newton-Raphson solver --------
#   > Iteration   0 - Residuals: 5.78e-04,   1.00e+00
#   > Iteration   1 - Residuals: 6.92e-06,   1.20e-02
#   > Iteration   2 - Residuals: 4.85e-07,   8.39e-04
#   > Iteration   3 - Residuals: 3.01e-08,   5.21e-05
#   > Iteration   4 - Residuals: 1.66e-09,   2.88e-06
#   > Iteration   5 - Residuals: 9.18e-11,   1.59e-07
#   > Iteration   6 - Residuals: 6.90e-12,   1.19e-08
#   > Iteration   7 - Residuals: 5.68e-13,   9.83e-10
# Solver Newton-Raphson finished with reason SOLVER_CONVERGED_ATOL
# Iterations:   7 - Residuals: 5.68e-13,   9.83e-10
# --------------- Exiting Newton-Raphson solver ---------
# Iteration: 117 | L=5.8166e-01, J=5.8291e-01, Vol=-6.5172e-04, γ=7.5000e-02, λ1=-1.9170e+00, Λ1=1.1644e+00
# --------------- Starting Newton-Raphson solver --------
#   > Iteration   0 - Residuals: 5.72e-04,   1.00e+00
#   > Iteration   1 - Residuals: 6.02e-06,   1.05e-02
#   > Iteration   2 - Residuals: 2.91e-07,   5.09e-04
#   > Iteration   3 - Residuals: 1.91e-08,   3.34e-05
#   > Iteration   4 - Residuals: 1.07e-09,   1.88e-06
#   > Iteration   5 - Residuals: 7.74e-11,   1.35e-07
#   > Iteration   6 - Residuals: 5.94e-12,   1.04e-08
#   > Iteration   7 - Residuals: 3.98e-13,   6.97e-10
# Solver Newton-Raphson finished with reason SOLVER_CONVERGED_ATOL
# Iterations:   7 - Residuals: 3.98e-13,   6.97e-10
# --------------- Exiting Newton-Raphson solver ---------
# Iteration: 118 | L=5.8166e-01, J=5.8274e-01, Vol=-5.6237e-04, γ=7.5000e-02, λ1=-1.9163e+00, Λ1=1.1644e+00
# --------------- Starting Newton-Raphson solver --------
#   > Iteration   0 - Residuals: 5.83e-04,   1.00e+00
#   > Iteration   1 - Residuals: 7.34e-06,   1.26e-02
#   > Iteration   2 - Residuals: 5.31e-07,   9.10e-04
#   > Iteration   3 - Residuals: 3.55e-08,   6.10e-05
#   > Iteration   4 - Residuals: 2.19e-09,   3.76e-06
#   > Iteration   5 - Residuals: 1.29e-10,   2.21e-07
#   > Iteration   6 - Residuals: 9.43e-12,   1.62e-08
#   > Iteration   7 - Residuals: 7.59e-13,   1.30e-09
# Solver Newton-Raphson finished with reason SOLVER_CONVERGED_ATOL
# Iterations:   7 - Residuals: 7.59e-13,   1.30e-09
# --------------- Exiting Newton-Raphson solver ---------
# Iteration: 119 | L=5.8168e-01, J=5.8267e-01, Vol=-5.2000e-04, γ=7.5000e-02, λ1=-1.9157e+00, Λ1=1.1644e+00
# (["./results/Unfitted_Thermal2D/Omega_in119.vtu"],)
