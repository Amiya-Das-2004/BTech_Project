# %% [markdown]
# ## Cantilever Beam Model
#
# **(Extrude Command Is used along with tag numbers)**

# %%
using Gmsh: gmsh

# Define dimensions
const L = 1000;           # length in mm
const W = 250;            # width in mm
const H = 200;            # height in mm
const h = 50;             # meshing size

# Initialize Gmsh
gmsh.initialize()
# (messages, warnings [1 => ON ] )
gmsh.option.setNumber("General.Terminal", 1)

# Define corner points
# gmsh.model.geo.addPoint(x, y, z, meshSize, pointTag)
gmsh.model.geo.addPoint(0.0, 0.0, 0, h, 1)
gmsh.model.geo.addPoint(W, 0.0, 0.0, h, 2)
gmsh.model.geo.addPoint(W, H, 0.0, h, 3)
gmsh.model.geo.addPoint(0, H, 0.0, h, 4)

# Bottom face lines
gmsh.model.geo.addLine(1, 2, 1)
gmsh.model.geo.addLine(2, 3, 2)
gmsh.model.geo.addLine(3, 4, 3)
gmsh.model.geo.addLine(4, 1, 4)

# Curve loop and plane surface for bottom
gmsh.model.geo.addCurveLoop([1, 2, 3, 4], 1)
gmsh.model.geo.addPlaneSurface([1], 1)

# Extrude to create 3D 
# ext = gmsh.model.geo.extrude([(dim, tag)], dx, dy, dz)
ext = gmsh.model.geo.extrude([(2, 1)], 0, 0, L)
print(ext)

# Entire 3D domain
gmsh.model.addPhysicalGroup(3, [1], 1)
gmsh.model.setPhysicalName(3, 1, "Domain")

# Face
gmsh.model.addPhysicalGroup(2, [26], 2)
gmsh.model.setPhysicalName(2, 2, "A")

# Face
gmsh.model.addPhysicalGroup(2, [17], 3)
gmsh.model.setPhysicalName(2, 3, "B")

# Face
gmsh.model.addPhysicalGroup(2, [21], 4)
gmsh.model.setPhysicalName(2, 4, "C")

# Face
gmsh.model.addPhysicalGroup(2, [25], 5)
gmsh.model.setPhysicalName(2, 5, "D")

# Face
gmsh.model.addPhysicalGroup(2, [13], 6)
gmsh.model.setPhysicalName(2, 6, "E")

# Face
gmsh.model.addPhysicalGroup(2, [1], 7)
gmsh.model.setPhysicalName(2, 7, "F")

# Synchronize geometry
gmsh.model.geo.synchronize()

# Generate 3D mesh
gmsh.model.mesh.generate(3)

# Create the folder (if it doesn't exist)
write_dir = joinpath(@__DIR__, "Model")
isdir(write_dir) || mkpath(write_dir)  

# Save mesh
gmsh.write(joinpath(write_dir, "3D_Beam_Extruded.msh"))

# Launch GUI
gmsh.fltk.run()  

# Finalize Gmsh
gmsh.finalize()
# Out:
# Tuple{Int32, Int32}[(2, 26), (3, 1), (2, 13), (2, 17), (2, 21), (2, 25)]
# Warning : Unknown entity of dimension 3 and tag 1 in physical group 1
# Warning : Unknown entity of dimension 2 and tag 26 in physical group 2
# Warning : Unknown entity of dimension 2 and tag 17 in physical group 3
# Warning : Unknown entity of dimension 2 and tag 21 in physical group 4
# Warning : Unknown entity of dimension 2 and tag 25 in physical group 5
# Warning : Unknown entity of dimension 2 and tag 13 in physical group 6
# Warning : Unknown entity of dimension 2 and tag 1 in physical group 7
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 6 (Line)
# Info    : [ 50%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 60%] Meshing curve 9 (Line)
# Info    : [ 70%] Meshing curve 11 (Line)
# Info    : [ 80%] Meshing curve 12 (Line)
# Info    : [ 90%] Meshing curve 16 (Line)
# Info    : [100%] Meshing curve 20 (Line)
# Info    : Done meshing 1D (Wall 0.00102711s, CPU 0s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 13 (Surface, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 17 (Surface, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 21 (Surface, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 25 (Surface, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 26 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0135212s, CPU 0.015625s)
# Info    : Meshing 3D...
# Info    : 3D Meshing 1 volume with 1 connected component
# Info    : Tetrahedrizing 510 nodes...
# Info    : Done tetrahedrizing 518 nodes (Wall 0.00411797s, CPU 0s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.00795794s, CPU 0s)
# Info    : Found volume 1
# Info    : It. 0 - 0 nodes created - worst tet radius 2.16936 (nodes removed 0 0)
# Info    : 3D refinement terminated (628 nodes total):
# Info    :  - 1 Delaunay cavities modified for star shapeness
# Info    :  - 0 nodes could not be inserted
# Info    :  - 2145 tetrahedra created in 0.00534105 sec. (401606 tets/s)
# Info    : 0 node relocations
# Info    : Done meshing 3D (Wall 0.0243909s, CPU 0.015625s)
# Info    : Optimizing mesh...
# Info    : Optimizing volume 1
# Info    : Optimization starts (volume = 5e+07) with worst = 0.0165801 / average = 0.756094:
# Info    : 0.00 < quality < 0.10 :        11 elements
# Info    : 0.10 < quality < 0.20 :        24 elements
# Info    : 0.20 < quality < 0.30 :        25 elements
# Info    : 0.30 < quality < 0.40 :        22 elements
# Info    : 0.40 < quality < 0.50 :        39 elements
# Info    : 0.50 < quality < 0.60 :       114 elements
# Info    : 0.60 < quality < 0.70 :       401 elements
# Info    : 0.70 < quality < 0.80 :       548 elements
# Info    : 0.80 < quality < 0.90 :       667 elements
# Info    : 0.90 < quality < 1.00 :       291 elements
# Info    : 59 edge swaps, 5 node relocations (volume = 5e+07): worst = 0.267869 / average = 0.773443 (Wall 0.000832081s, CPU 0s)
# Info    : 61 edge swaps, 6 node relocations (volume = 5e+07): worst = 0.291297 / average = 0.77407 (Wall 0.000961781s, CPU 0s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         1 elements
# Info    : 0.30 < quality < 0.40 :        23 elements
# Info    : 0.40 < quality < 0.50 :        35 elements
# Info    : 0.50 < quality < 0.60 :       120 elements
# Info    : 0.60 < quality < 0.70 :       387 elements
# Info    : 0.70 < quality < 0.80 :       556 elements
# Info    : 0.80 < quality < 0.90 :       675 elements
# Info    : 0.90 < quality < 1.00 :       292 elements
# Info    : Done optimizing mesh (Wall 0.00217605s, CPU 0.015625s)
# Info    : 628 nodes 3232 elements
# Info    : Writing 'c:\Users\IIT BBSR\Desktop\Amiya\BTP\Gmesh_Model\Model\3D_Beam_Extruded.msh'...
# Info    : Done writing 'c:\Users\IIT BBSR\Desktop\Amiya\BTP\Gmesh_Model\Model\3D_Beam_Extruded.msh'
# -------------------------------------------------------
# Version       : 4.13.1
# License       : GNU General Public License
# Build OS      : Windows64-sdk
# Build date    : 19700101
# Build host    : amdci7.julia.csail.mit.edu
# Build options : 64Bit ALGLIB[contrib] ANN[contrib] Bamg Blossom Cairo DIntegration DomHex Eigen[contrib] Fltk GMP Gmm[contrib] Hxt Jpeg Kbipack MathEx[contrib] Mesh Metis[contrib] Mmg Mpeg Netgen Nii2mesh NoSocklenT ONELAB ONELABMetamodel OpenCASCADE OpenCASCADE-CAF OpenGL OpenMP OptHom Parser Plugins Png Post QuadMeshingTools QuadTri Solver TetGen/BR TinyXML2[contrib] Untangle Voro++[contrib] WinslowUntangler Zlib
# FLTK version  : 1.3.8
# OCC version   : 7.7.2
# Packaged by   : root
# Web site      : https://gmsh.info
# Issue tracker : https://gitlab.onelab.info/gmsh/gmsh/issues
# -------------------------------------------------------

# %%
using GridapGmsh
using Gridap

# %%
# Check For Meshing
mesh_name = "3D_Beam_Extruded.msh"
mesh_file = joinpath(@__DIR__, mesh_name)

isfile(mesh_file) || error("Path does not exist: $mesh_file")
model_check = GmshDiscreteModel(mesh_file)

result_path = joinpath(@__DIR__, "..", "..", "..", "Result", "Model_Check","3D_Beam_Extruded")
isdir(result_path) || mkpath(result_path)

writevtk(model_check, joinpath(result_path, "model_check"))
