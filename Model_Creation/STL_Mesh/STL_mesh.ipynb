# %%
using Gmsh: gmsh

# Define dimensions
const L = 1000;           # length in mm
const W = 400;            # width in mm
const H = 50;            # height in mm
const h = 10;             # meshing size

# Initialize Gmsh
gmsh.initialize()
# (messages, warnings [1 => ON ] )
gmsh.option.setNumber("General.Terminal", 1)

# Define corner points
# gmsh.model.geo.addPoint(x, y, z, meshSize, pointTag)
gmsh.model.geo.addPoint(0.0, 0.0, 0, h, 1)
gmsh.model.geo.addPoint(W, 0.0, 0.0, h, 2)
gmsh.model.geo.addPoint(W, H, 0.0, h, 3)
gmsh.model.geo.addPoint(0, H, 0.0, h, 4)

# Bottom face lines
gmsh.model.geo.addLine(1, 2, 1)
gmsh.model.geo.addLine(2, 3, 2)
gmsh.model.geo.addLine(3, 4, 3)
gmsh.model.geo.addLine(4, 1, 4)

# Curve loop and plane surface for bottom
gmsh.model.geo.addCurveLoop([1, 2, 3, 4], 1)
gmsh.model.geo.addPlaneSurface([1], 1)

# Extrude to create 3D 
# ext = gmsh.model.geo.extrude([(dim, tag)], dx, dy, dz)
ext = gmsh.model.geo.extrude([(2, 1)], 0, 0, L)
print(ext)

# Entire 3D domain
gmsh.model.addPhysicalGroup(3, [1], 1)
gmsh.model.setPhysicalName(3, 1, "Domain")

# Face
gmsh.model.addPhysicalGroup(2, [1], 2)
gmsh.model.setPhysicalName(2, 2, "A")

# Face
gmsh.model.addPhysicalGroup(2, [26], 3)
gmsh.model.setPhysicalName(2, 3, "B")

# Face
gmsh.model.addPhysicalGroup(2, [13], 4)
gmsh.model.setPhysicalName(2, 4, "C")

# Face
gmsh.model.addPhysicalGroup(2, [17], 5)
gmsh.model.setPhysicalName(2, 5, "D")

# Face
gmsh.model.addPhysicalGroup(2, [21], 6)
gmsh.model.setPhysicalName(2, 6, "E")

# Face
gmsh.model.addPhysicalGroup(2, [25], 7)
gmsh.model.setPhysicalName(2, 7, "F")

# Synchronize geometry
gmsh.model.geo.synchronize()

# Generate 3D mesh
gmsh.model.mesh.generate(3)

# Create the folder (if it doesn't exist)
write_dir = joinpath(@__DIR__, "Unfitted_Mesh")
isdir(write_dir) || mkpath(write_dir)  

# Save mesh
gmsh.write(joinpath(write_dir, "Box_Mesh.stl"))

# Launch GUI
gmsh.fltk.run()  

# Finalize Gmsh
gmsh.finalize()
# Out:
# Tuple{Int32, Int32}[(2, 26), (3, 1), (2, 13), (2, 17), (2, 21), (2, 25)]
# WARNING: redefinition of constant Main.W. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant Main.H. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant Main.h. This may fail, cause incorrect answers, or produce other errors.
# Warning : Unknown entity of dimension 3 and tag 1 in physical group 1
# Warning : Unknown entity of dimension 2 and tag 1 in physical group 2
# Warning : Unknown entity of dimension 2 and tag 26 in physical group 3
# Warning : Unknown entity of dimension 2 and tag 13 in physical group 4
# Warning : Unknown entity of dimension 2 and tag 17 in physical group 5
# Warning : Unknown entity of dimension 2 and tag 21 in physical group 6
# Warning : Unknown entity of dimension 2 and tag 25 in physical group 7
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 6 (Line)
# Info    : [ 50%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 60%] Meshing curve 9 (Line)
# Info    : [ 70%] Meshing curve 11 (Line)
# Info    : [ 80%] Meshing curve 12 (Line)
# Info    : [ 90%] Meshing curve 16 (Line)
# Info    : [100%] Meshing curve 20 (Line)
# Info    : Done meshing 1D (Wall 0.00108576s, CPU 0s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 13 (Surface, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 17 (Surface, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 21 (Surface, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 25 (Surface, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 26 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.346469s, CPU 0.34375s)
# Info    : Meshing 3D...
# Info    : 3D Meshing 1 volume with 1 connected component
# Info    : Tetrahedrizing 11039 nodes...
# Info    : Done tetrahedrizing 11047 nodes (Wall 0.131295s, CPU 0.140625s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    :  - Added 2 Steiner points
# Info    : Done reconstructing mesh (Wall 0.359682s, CPU 0.34375s)
# Info    : Found volume 1
# Info    : It. 0 - 0 nodes created - worst tet radius 8.30291 (nodes removed 0 0)
# Info    : It. 500 - 476 nodes created - worst tet radius 2.28041 (nodes removed 0 24)
# Info    : It. 1000 - 975 nodes created - worst tet radius 1.79624 (nodes removed 0 25)
# Info    : It. 1500 - 1475 nodes created - worst tet radius 1.69039 (nodes removed 0 25)
# Info    : It. 2000 - 1975 nodes created - worst tet radius 1.61363 (nodes removed 0 25)
# Info    : It. 2500 - 2475 nodes created - worst tet radius 1.4989 (nodes removed 0 25)
# Info    : It. 3000 - 2975 nodes created - worst tet radius 1.39747 (nodes removed 0 25)
# Info    : It. 3500 - 3475 nodes created - worst tet radius 1.33871 (nodes removed 0 25)
# Info    : It. 4000 - 3975 nodes created - worst tet radius 1.29728 (nodes removed 0 25)
# Info    : It. 4500 - 4475 nodes created - worst tet radius 1.24503 (nodes removed 0 25)
# Info    : It. 5000 - 4975 nodes created - worst tet radius 1.20649 (nodes removed 0 25)
# Info    : It. 5500 - 5475 nodes created - worst tet radius 1.17986 (nodes removed 0 25)
# Info    : It. 6000 - 5975 nodes created - worst tet radius 1.15754 (nodes removed 0 25)
# Info    : It. 6500 - 6475 nodes created - worst tet radius 1.13438 (nodes removed 0 25)
# Info    : It. 7000 - 6975 nodes created - worst tet radius 1.11171 (nodes removed 0 25)
# Info    : It. 7500 - 7475 nodes created - worst tet radius 1.08902 (nodes removed 0 25)
# Info    : It. 8000 - 7975 nodes created - worst tet radius 1.06827 (nodes removed 0 25)
# Info    : It. 8500 - 8475 nodes created - worst tet radius 1.04922 (nodes removed 0 25)
# Info    : It. 9000 - 8975 nodes created - worst tet radius 1.03121 (nodes removed 0 25)
# Info    : It. 9500 - 9475 nodes created - worst tet radius 1.01336 (nodes removed 0 25)
# Info    : 3D refinement terminated (20958 nodes total):
# Info    :  - 5 Delaunay cavities modified for star shapeness
# Info    :  - 25 nodes could not be inserted
# Info    :  - 97869 tetrahedra created in 0.595423 sec. (164368 tets/s)
# Info    : 0 node relocations
# Info    : Done meshing 3D (Wall 1.60381s, CPU 1.5625s)
# Info    : Optimizing mesh...
# Info    : Optimizing volume 1
# Info    : Optimization starts (volume = 2e+07) with worst = 0.00529365 / average = 0.768791:
# Info    : 0.00 < quality < 0.10 :       248 elements
# Info    : 0.10 < quality < 0.20 :       657 elements
# Info    : 0.20 < quality < 0.30 :      1121 elements
# Info    : 0.30 < quality < 0.40 :      1819 elements
# Info    : 0.40 < quality < 0.50 :      2808 elements
# Info    : 0.50 < quality < 0.60 :      4736 elements
# Info    : 0.60 < quality < 0.70 :     11257 elements
# Info    : 0.70 < quality < 0.80 :     24981 elements
# Info    : 0.80 < quality < 0.90 :     34579 elements
# Info    : 0.90 < quality < 1.00 :     15660 elements
# Info    : 2001 edge swaps, 42 node relocations (volume = 2e+07): worst = 0.131395 / average = 0.781621 (Wall 0.0444298s, CPU 0.046875s)
# Info    : 2025 edge swaps, 44 node relocations (volume = 2e+07): worst = 0.198304 / average = 0.781746 (Wall 0.0548828s, CPU 0.046875s)
# Info    : 2027 edge swaps, 45 node relocations (volume = 2e+07): worst = 0.245148 / average = 0.781749 (Wall 0.064599s, CPU 0.0625s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         2 elements
# Info    : 0.30 < quality < 0.40 :      1777 elements
# Info    : 0.40 < quality < 0.50 :      2681 elements
# Info    : 0.50 < quality < 0.60 :      4629 elements
# Info    : 0.60 < quality < 0.70 :     11320 elements
# Info    : 0.70 < quality < 0.80 :     25122 elements
# Info    : 0.80 < quality < 0.90 :     34929 elements
# Info    : 0.90 < quality < 1.00 :     15583 elements
# Info    : Done optimizing mesh (Wall 0.174483s, CPU 0.140625s)
# Info    : 20956 nodes 118708 elements
# Info    : Writing 'c:\Users\IIT BBSR\Desktop\Amiya\BTP\Model_Creation\STL_Mesh\Unfitted_Mesh\Box_Mesh.stl'...
# Info    : Done writing 'c:\Users\IIT BBSR\Desktop\Amiya\BTP\Model_Creation\STL_Mesh\Unfitted_Mesh\Box_Mesh.stl'
# -------------------------------------------------------
# Version       : 4.13.1
# License       : GNU General Public License
# Build OS      : Windows64-sdk
# Build date    : 19700101
# Build host    : amdci7.julia.csail.mit.edu
# Build options : 64Bit ALGLIB[contrib] ANN[contrib] Bamg Blossom Cairo DIntegration DomHex Eigen[contrib] Fltk GMP Gmm[contrib] Hxt Jpeg Kbipack MathEx[contrib] Mesh Metis[contrib] Mmg Mpeg Netgen Nii2mesh NoSocklenT ONELAB ONELABMetamodel OpenCASCADE OpenCASCADE-CAF OpenGL OpenMP OptHom Parser Plugins Png Post QuadMeshingTools QuadTri Solver TetGen/BR TinyXML2[contrib] Untangle Voro++[contrib] WinslowUntangler Zlib
# FLTK version  : 1.3.8
# OCC version   : 7.7.2
# Packaged by   : root
# Web site      : https://gmsh.info
# Issue tracker : https://gitlab.onelab.info/gmsh/gmsh/issues
# -------------------------------------------------------
